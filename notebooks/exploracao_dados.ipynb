# %% [markdown]
# # 1.Importação de bibliotecas

# %%
# Notebook de exploração e tratamento de dados
# NÃO utilizar Streamlit neste arquivo vistoq ue o mesmo é para rodar a aplicação

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import requests
# !pip install xlrd

# %% [markdown]
# # 2. Importação da base de dados e conversão

# %%
# URL RAW do GitHub (arquivo Excel real)
url = "https://raw.githubusercontent.com/elissouza2023/DasboardExportacoesAco/main/data/raw/Performance-Mensal_2025.12.xls"

# Baixar o arquivo
response = requests.get(url)
response.raise_for_status()  # boa prática

with open("Performance-Mensal_2025.12.xls", "wb") as f:
    f.write(response.content)

# Ler o Excel (engine explícito para .xls)
df = pd.read_excel("Performance-Mensal_2025.12.xls", engine="xlrd")

df.head()
# Out:
#     Siderurgia Brasileira / Brazilian Steel Industry Unnamed: 1 Unnamed: 2  \
# 0  Comparativo Performance Mensal / Monthly Perfo...        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2                       Especificação\nSpecification       2013        NaN
# 3                                                NaN   Jan\nJan   Fev\nFeb
# 4                                                NaN        NaN        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3   Mar\nMar   Abr\nApr   Mai\nMay   Jun\nJun   Jul\nJul   Ago\nAug
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9  ... Unnamed: 148 Unnamed: 149 Unnamed: 150 Unnamed: 151  \
# ...

# %% [markdown]
# # 3. Tratamento da Planilha

# %%
# lendo a planilha em excel para evitar erros de formatação, entendendo a estrutura
df_raw = pd.read_excel(
    "Performance-Mensal_2025.12.xls",
    header=None
)

df_raw.head(15)
# Out:
#                                                   0         1         2    \
# 0    Siderurgia Brasileira / Brazilian Steel Industry       NaN       NaN
# 1   Comparativo Performance Mensal / Monthly Perfo...       NaN       NaN
# 2                                                 NaN       NaN       NaN
# 3                        Especificação\nSpecification      2013       NaN
# 4                                                 NaN  Jan\nJan  Fev\nFeb
# 5                                                 NaN       NaN       NaN
# 6                               Produção / Production       NaN       NaN
# 7                             Aço Bruto / Crude Steel  2769.437  2574.894
# 8                     Laminados / Rolled Products (*)  2051.441  1942.836
# 9                              Planos / Flat Products  1202.482  1144.078
# 10                             Longos / Long Products   848.959   798.758
# 11  Semiacabados P/ Vendas /\nSemifinished Product...   470.371   480.793
# ...

# %%
#lendo apartir da linha 4 devido linhas em branco de formatação de titulos
df = pd.read_excel(
    "Performance-Mensal_2025.12.xls",
    skiprows=4,      # pula título e textos
    header=0
)

# %%
#Contando linhas e colunas
df.columns
df.head()
# Out:
#                         Unnamed: 0  Jan\nJan  Fev\nFeb  Mar\nMar  Abr\nApr  \
# 0                              NaN       NaN       NaN       NaN       NaN
# 1            Produção / Production       NaN       NaN       NaN       NaN
# 2          Aço Bruto / Crude Steel  2769.437  2574.894  2858.521  2913.622
# 3  Laminados / Rolled Products (*)  2051.441  1942.836  2194.384  2211.587
# 4           Planos / Flat Products  1202.482  1144.078  1261.646  1233.065
#
#    Mai\nMay  Jun\nJun  Jul\nJul  Ago\nAug  Set\nSep  ...  Abr\nApr.12  \
# 0       NaN       NaN       NaN       NaN       NaN  ...          NaN
# 1       NaN       NaN       NaN       NaN       NaN  ...          NaN
# 2  2999.775  2836.535  2918.241  2976.770  2981.309  ...     2644.864
# 3  2354.716  2284.417  2252.236  2257.548  2181.567  ...     2012.514
# 4  1311.414  1285.362  1251.395  1270.671  1229.652  ...     1168.752
#
#    Mai\nMay.12  Jun\nJun.12  Jul\nJul.12  Ago\nAug.12  Set\nSep.9  \
# ...

# %% [markdown]
# # 4. Tratamento de linhas e colunas

# %%
#Remover colunas vazias
df = df.dropna(axis=1, how="all")
#Preencher células mescladas “quebradas”
df.iloc[:, 0] = df.iloc[:, 0].ffill()
#Padronizar nomes de colunas
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
)

# %%
# Visualizando as colunas
df.columns
# Out:
# Index(['unnamed:_0', 'jan\njan', 'fev\nfeb', 'mar\nmar', 'abr\napr',
#        'mai\nmay', 'jun\njun', 'jul\njul', 'ago\naug', 'set\nsep',
#        ...
#        'abr\napr.12', 'mai\nmay.12', 'jun\njun.12', 'jul\njul.12',
#        'ago\naug.12', 'set\nsep.9', 'out\noct.12', 'nov\nnov.12', 'dez\ndec.5',
#        'unnamed:_157'],
#       dtype='object', length=158)

# %%
for col in df.columns:
    print(col)
# Out:
# unnamed:_0
# jan
# jan
# fev
# feb
# mar
# mar
# abr
# apr
# mai
# may
# jun
# jun
# jul
# jul
# ago
# aug
# set
# sep
# out
# oct
# nov
# nov
# dez
# dez
# jan
# jan.1
# fev
# feb.1
# mar
# mar.1
# abr
# apr.1
# mai
# may.1
# jun
# jun.1
# jul
# jul.1
# ago
# aug.1
# set
# sep.1
# out
# oct.1
# nov
# nov.1
# dez
# dez.1
# jan
# jan.2
# fev
# feb.2
# mar
# mar.2
# abr
# apr.2
# mai
# may.2
# jun
# jun.2
# jul
# jul.2
# ago
# aug.2
# set
# sep.2
# out
# oct.2
# nov
# nov.2
# dez
# dez.2
# jan
# jan.3
# fev
# feb.3
# mar
# mar.3
# abr
# apr.3
# mai
# may.3
# jun
# jun.3
# jul
# jul.3
# ago
# aug.3
# set
# sep.3
# out
# oct.3
# nov
# nov.3
# dez
# dez.3
# jan
# jan.4
# fev
# feb.4
# mar
# mar.4
# abr
# apr.4
# mai
# may.4
# jun
# jun.4
# jul
# jul.4
# ago
# aug.4
# set
# sep.4
# out
# oct.4
# nov
# nov.4
# dez
# dez.4
# jan
# jan.5
# fev
# feb.5
# mar
# mar.5
# abr
# apr.5
# mai
# may.5
# jun
# jun.5
# jul
# jul.5
# ago
# aug.5
# set
# sep.5
# out
# oct.5
# nov
# nov.5
# dez
# dez.5
# ...

# %%
# Renomeando a coluna Principal
df = df.rename(columns={"unnamed:_0": "produto"})
df.columns
# Out:
# Index(['produto', 'jan\njan', 'fev\nfeb', 'mar\nmar', 'abr\napr', 'mai\nmay',
#        'jun\njun', 'jul\njul', 'ago\naug', 'set\nsep',
#        ...
#        'abr\napr.12', 'mai\nmay.12', 'jun\njun.12', 'jul\njul.12',
#        'ago\naug.12', 'set\nsep.9', 'out\noct.12', 'nov\nnov.12', 'dez\ndec.5',
#        'unnamed:_157'],
#       dtype='object', length=158)

# %%
#Remover colunas duplicadas em inglês
meses_pt = [
    "jan", "fev", "mar", "abr", "mai", "jun",
    "jul", "ago", "set", "out", "nov", "dez"
]

# %%
#Filtrando as colunas válidas
colunas_validas = ["produto"] + [
    col for col in df.columns
    if any(col.startswith(mes) for mes in meses_pt)
]

df = df[colunas_validas]

# %%
#Criar o eixo temporal (ANO + MÊS)
anos = list(range(2013, 2026))

# %%
#Mapear colunas para (ano, mês)
novas_colunas = ["produto"]

i = 0
for ano in anos:
    for mes in meses_pt:
        if i + 1 < len(df.columns):
            novas_colunas.append(f"{ano}_{mes}")
            i += 1

df.columns = novas_colunas

# %%
# Salvar base tratada em formato largo (intermediário)
df.to_csv(
    "exportacoes_aco_tratado_largo.csv",
    index=False,
    encoding="utf-8"
)

# %%
#Converter para formato LONGO (ideal para dashboard)
df_long = df.melt(
    id_vars="produto",
    var_name="ano_mes",
    value_name="volume"
)

# %%
#Separar ano e mês:
df_long[["ano", "mes"]] = df_long["ano_mes"].str.split("_", expand=True)

# %%
#Limpar
df_long = df_long.dropna(subset=["volume"])

# %% [markdown]
# # 5. Visualizando os dados

# %%
df.head()
# Out:
#                            produto  2013_jan  2013_fev  2013_mar  2013_abr  \
# 0                              NaN       NaN       NaN       NaN       NaN
# 1            Produção / Production       NaN       NaN       NaN       NaN
# 2          Aço Bruto / Crude Steel  2769.437  2574.894  2858.521  2913.622
# 3  Laminados / Rolled Products (*)  2051.441  1942.836  2194.384  2211.587
# 4           Planos / Flat Products  1202.482  1144.078  1261.646  1233.065
#
#    2013_mai  2013_jun  2013_jul  2013_ago  2013_set  ...  2025_mar  2025_abr  \
# 0       NaN       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2  2999.775  2836.535  2918.241  2976.770  2981.309  ...  2881.835  2644.864
# 3  2354.716  2284.417  2252.236  2257.548  2181.567  ...  2042.231  2012.514
# 4  1311.414  1285.362  1251.395  1270.671  1229.652  ...  1148.143  1168.752
#
# ...

# %%
#VErificando tamanho
df.shape
# Out:
# (49, 157)

# %%
#Ver todas as colunas (sem cortar)
pd.set_option("display.max_columns", None)
df.head()
# Out:
#                            produto  2013_jan  2013_fev  2013_mar  2013_abr  \
# 0                              NaN       NaN       NaN       NaN       NaN
# 1            Produção / Production       NaN       NaN       NaN       NaN
# 2          Aço Bruto / Crude Steel  2769.437  2574.894  2858.521  2913.622
# 3  Laminados / Rolled Products (*)  2051.441  1942.836  2194.384  2211.587
# 4           Planos / Flat Products  1202.482  1144.078  1261.646  1233.065
#
#    2013_mai  2013_jun  2013_jul  2013_ago  2013_set  2013_out  2013_nov  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2  2999.775  2836.535  2918.241  2976.770  2981.309  2980.320  2727.159
# 3  2354.716  2284.417  2252.236  2257.548  2181.567  2309.355  2199.432
# 4  1311.414  1285.362  1251.395  1270.671  1229.652  1321.820  1218.682
#
#    2013_dez  2014_jan  2014_fev  2014_mar  2014_abr  2014_mai  2014_jun  \
# ...

# %%
#voltar ao padrão
pd.reset_option("display.max_columns")

# %%
# Entender a estrutura
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Columns: 157 entries, produto to 2025_dez
# dtypes: float64(156), object(1)
# memory usage: 60.2+ KB

# %%
#Visualizar amostra aleatória (evita viés)
df.sample(5)
# Out:
#                                               produto  2013_jan  2013_fev  \
# 45  (**) Vendas faturadas pelas usinas. / Sales in...       NaN       NaN
# 12                             Planos / Flat Products  1088.146  1019.531
# 10               Vendas Internas / Domestic Sales (*)  1905.819  1791.619
# 22                                     Placas / Slabs   426.772   354.891
# 34                              Importações / Imports       NaN       NaN
#
#     2013_mar  2013_abr  2013_mai  2013_jun  2013_jul  2013_ago  2013_set  ...  \
# 45       NaN       NaN       NaN       NaN       NaN       NaN       NaN  ...
# 12  1141.455  1137.847  1228.297  1225.625  1147.725  1220.747  1183.966  ...
# 10  2062.865  2074.205  2193.013  2123.333  2095.949  2226.363  2111.765  ...
# 22   435.865   348.159   292.198   274.882   283.569   385.887   434.833  ...
# 34       NaN       NaN       NaN       NaN       NaN       NaN       NaN  ...
#
# ...

# %%
#Visualizar o DataFrame LONGO
df_long.head(10)
# Out:
#                                               produto   ano_mes    volume  \
# 2                             Aço Bruto / Crude Steel  2013_jan  2769.437
# 3                     Laminados / Rolled Products (*)  2013_jan  2051.441
# 4                              Planos / Flat Products  2013_jan  1202.482
# 5                              Longos / Long Products  2013_jan   848.959
# 6   Semiacabados P/ Vendas /\nSemifinished Product...  2013_jan   470.371
# 7                                      Placas / Slabs  2013_jan   394.660
# 8       Blocos e Tarugos / Ingots, Blooms and Billets  2013_jan    75.711
# 9                               Ferro-Gusa / Pig Iron  2013_jan  2178.041
# 10               Vendas Internas / Domestic Sales (*)  2013_jan  1905.819
# 11                        Laminados / Rolled Products  2013_jan  1852.831
#
#      ano  mes
# 2   2013  jan
# 3   2013  jan
# 4   2013  jan
# 5   2013  jan
# 6   2013  jan
# 7   2013  jan
# 8   2013  jan
# 9   2013  jan
# ...

# %%
df_long.sample(10)
# Out:
#                                                 produto   ano_mes    volume  \
# 7517                             Longos / Long Products  2025_out    72.693
# 1241      Blocos e Tarugos / Ingots, Blooms and Billets  2015_fev     9.457
# 5433  Longos / Long Products\n(Inclui Blocos e Tarug...  2022_mar   891.910
# 5080                       (US$ Milhões / US$ Millions)  2021_ago   867.629
# 6264      Consumo Aparente / Apparent Consumption (***)  2023_ago  2130.662
# 1748                       (US$ Milhões / US$ Millions)  2015_dez   546.000
# 3804      Blocos e Tarugos / Ingots, Blooms and Billets  2019_jun     2.988
# 2537  Semiacabados P/ Vendas /\nSemifinished Product...  2017_abr     1.920
# 6305                       (US$ Milhões / US$ Millions)  2023_set   661.682
# 6437                        Laminados / Rolled Products  2023_dez   213.847
#
#        ano  mes
# 7517  2025  out
# 1241  2015  fev
# 5433  2022  mar
# 5080  2021  ago
# 6264  2023  ago
# 1748  2015  dez
# ...

# %%
#Conferir valores faltantes
df_long.isna().sum()
# Out:
# produto    0
# ano_mes    0
# volume     0
# ano        0
# mes        0
# dtype: int64

# %%
#Conferir distribuição por ano
df_long["ano"].value_counts().sort_index()
# Out:
# ano
# 2013    468
# 2014    468
# 2015    468
# 2016    468
# 2017    468
# 2018    468
# 2019    468
# 2020    468
# 2021    468
# 2022    468
# 2023    468
# 2024    468
# 2025    468
# Name: count, dtype: int64

# %%
# Conferir produtos únicos
df_long["produto"].unique()
# Out:
# array(['Aço Bruto / Crude Steel', 'Laminados / Rolled Products (*)',
#        'Planos / Flat Products', 'Longos / Long Products',
#        'Semiacabados P/ Vendas /\nSemifinished Products for Sale (*)',
#        'Placas / Slabs', 'Blocos e Tarugos / Ingots, Blooms and Billets',
#        'Ferro-Gusa / Pig Iron', 'Vendas Internas / Domestic Sales (*)',
#        'Laminados / Rolled Products',
#        'Semiacabados P/ Vendas /\nSemifinished Products for Sale',
#        'Vendas Externas / Foreign Market (**)',
#        'Total (Mil t / Thousand Tonnes)', '(US$ Milhões / US$ Millions)',
#        'Consumo Aparente / Apparent Consumption (***)',
#        'Planos / Flat Products\n(Inclui Placas / Included Slabs)',
#        'Longos / Long Products\n(Inclui Blocos e Tarugos / Included Ingots, Blooms and Billets)'],
#       dtype=object)

# %%
#Visualização “bonita” no Colab
df_long.head(20).style.format({"volume": "{:,.0f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_f9454" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9454_level0_col0" class="col_heading level0 col0" >produto</th>
#       <th id="T_f9454_level0_col1" class="col_heading level0 col1" >ano_mes</th>
#       <th id="T_f9454_level0_col2" class="col_heading level0 col2" >volume</th>
#       <th id="T_f9454_level0_col3" class="col_heading level0 col3" >ano</th>
#       <th id="T_f9454_level0_col4" class="col_heading level0 col4" >mes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9454_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_f9454_row0_col0" class="data row0 col0" >Aço Bruto / Crude Steel</td>
#       <td id="T_f9454_row0_col1" class="data row0 col1" >2013_jan</td>
#       <td id="T_f9454_row0_col2" class="data row0 col2" >2,769</td>
#       <td id="T_f9454_row0_col3" class="data row0 col3" >2013</td>
# ...

# %% [markdown]
# 5.Salvando a Exploração de dados

# %%
caminho_saida = "exportacoes_aco_mensal_tratado.csv"

# %%
df_long.to_csv(
    caminho_saida,
    index=False,
    encoding="utf-8"
)

# %%
#verificando se salvou
# !ls
# Out:
# exportacoes_aco_mensal_tratado.csv  Performance-Mensal_2025.12.xls
# exportacoes_aco_tratado_largo.csv   sample_data
